# %%
import os
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, Flatten
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.applications import ResNet50
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.metrics import Precision, Recall
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import pandas as pd

# Set image dimensions
IMG_HEIGHT, IMG_WIDTH = 224, 224
batch_size = 32
train_data_dir = 'FER2013/train'
val_data_dir = 'FER2013/test'

# Initialize data generators training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
)

# Initialize data generators validation
val_datagen = ImageDataGenerator(
    rescale=1./255,
)

# Train data generator
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Validation data generator
validation_generator = val_datagen.flow_from_directory(
    val_data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Load ResNet50 model, pre-trained on ImageNet, without the top layer
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# Freezeing layer
for layer in base_model.layers[:20]:
    layer.trainable = False

# Create the top model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu', kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(7, activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy', Recall(name='recall'), Precision(name='precision')])
model.summary()

# Setup callbacks for efficient training
checkpoint = ModelCheckpoint('cp_resnet_test_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-7, verbose=1)

# Training process
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.n // validation_generator.batch_size,
    epochs=40,  # Increased epochs for more training
    callbacks=[checkpoint, reduce_lr],
    verbose=1
)

# Save model to local machine
model.save('resnet50_test_model_fer.h5')

# Plotting the training results 
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

plt.subplot(1, 2, 1)
plt.plot(history.history['recall'], label='Train Recall')
plt.plot(history.history['val_recall'], label='Validation Recall')
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()

plt.subplot(1, 2, 2)
plt.plot(history.history['precision'], label='Train Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

validation_generator.reset()
val_steps = validation_generator.n // validation_generator.batch_size + 1
y_true = []
y_pred = []

# Predict on validation data
for _ in range(val_steps):
    x, y = next(validation_generator)
    y_true.extend(np.argmax(y, axis=1))
    y_pred.extend(np.argmax(model.predict(x), axis=1))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=validation_generator.class_indices.keys())

# Plot confusion matrix
plt.figure(figsize=(10, 8))
cm_display.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.title('Confusion Matrix - Resnet-50')
plt.show()
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_2   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 256)               524544
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 24,115,079
# Trainable params: 23,959,751
# Non-trainable params: 155,328
# _________________________________________________________________
# Epoch 1/40
# 897/897 [==============================] - ETA: 0s - loss: 5.7785 - accuracy: 0.3560 - recall: 0.1708 - precision: 0.4938
# Epoch 1: val_accuracy improved from -inf to 0.44922, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 230s 251ms/step - loss: 5.7785 - accuracy: 0.3560 - recall: 0.1708 - precision: 0.4938 - val_loss: 4.7131 - val_accuracy: 0.4492 - val_recall: 0.2475 - val_precision: 0.7291 - lr: 1.0000e-04
# Epoch 2/40
# 897/897 [==============================] - ETA: 0s - loss: 3.8211 - accuracy: 0.4855 - recall: 0.3034 - precision: 0.6588
# Epoch 2: val_accuracy improved from 0.44922 to 0.52302, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 220s 245ms/step - loss: 3.8211 - accuracy: 0.4855 - recall: 0.3034 - precision: 0.6588 - val_loss: 3.0905 - val_accuracy: 0.5230 - val_recall: 0.4436 - val_precision: 0.5948 - lr: 1.0000e-04
# Epoch 3/40
# 897/897 [==============================] - ETA: 0s - loss: 2.5070 - accuracy: 0.5394 - recall: 0.3633 - precision: 0.6993
# Epoch 3: val_accuracy improved from 0.52302 to 0.60198, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 225s 250ms/step - loss: 2.5070 - accuracy: 0.5394 - recall: 0.3633 - precision: 0.6993 - val_loss: 1.9147 - val_accuracy: 0.6020 - val_recall: 0.4777 - val_precision: 0.7214 - lr: 1.0000e-04
# Epoch 4/40
# 897/897 [==============================] - ETA: 0s - loss: 1.8420 - accuracy: 0.5547 - recall: 0.3953 - precision: 0.6935
# Epoch 4: val_accuracy did not improve from 0.60198
# 897/897 [==============================] - 245s 273ms/step - loss: 1.8420 - accuracy: 0.5547 - recall: 0.3953 - precision: 0.6935 - val_loss: 1.5749 - val_accuracy: 0.5633 - val_recall: 0.4219 - val_precision: 0.6968 - lr: 1.0000e-04
# Epoch 5/40
# 897/897 [==============================] - ETA: 0s - loss: 1.4665 - accuracy: 0.5718 - recall: 0.4168 - precision: 0.7089
# Epoch 5: val_accuracy did not improve from 0.60198
# 897/897 [==============================] - 240s 267ms/step - loss: 1.4665 - accuracy: 0.5718 - recall: 0.4168 - precision: 0.7089 - val_loss: 1.3244 - val_accuracy: 0.5912 - val_recall: 0.4837 - val_precision: 0.6924 - lr: 1.0000e-04
# Epoch 6/40
# 897/897 [==============================] - ETA: 0s - loss: 1.2504 - accuracy: 0.5961 - recall: 0.4462 - precision: 0.7294
# Epoch 6: val_accuracy did not improve from 0.60198
# 897/897 [==============================] - 222s 247ms/step - loss: 1.2504 - accuracy: 0.5961 - recall: 0.4462 - precision: 0.7294 - val_loss: 4.1730 - val_accuracy: 0.1780 - val_recall: 0.1723 - val_precision: 0.1757 - lr: 1.0000e-04
# Epoch 7/40
# 897/897 [==============================] - ETA: 0s - loss: 1.1632 - accuracy: 0.6079 - recall: 0.4613 - precision: 0.7347
# Epoch 7: val_accuracy did not improve from 0.60198
# 897/897 [==============================] - 226s 252ms/step - loss: 1.1632 - accuracy: 0.6079 - recall: 0.4613 - precision: 0.7347 - val_loss: 1.4458 - val_accuracy: 0.5318 - val_recall: 0.4784 - val_precision: 0.5790 - lr: 1.0000e-04
# Epoch 8/40
# 897/897 [==============================] - ETA: 0s - loss: 1.1068 - accuracy: 0.6151 - recall: 0.4720 - precision: 0.7398
# Epoch 8: val_accuracy improved from 0.60198 to 0.61998, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 230s 256ms/step - loss: 1.1068 - accuracy: 0.6151 - recall: 0.4720 - precision: 0.7398 - val_loss: 1.0623 - val_accuracy: 0.6200 - val_recall: 0.5294 - val_precision: 0.7170 - lr: 1.0000e-04
# Epoch 9/40
# 897/897 [==============================] - ETA: 0s - loss: 1.0598 - accuracy: 0.6264 - recall: 0.4910 - precision: 0.7475
# Epoch 9: val_accuracy did not improve from 0.61998
# 897/897 [==============================] - 228s 254ms/step - loss: 1.0598 - accuracy: 0.6264 - recall: 0.4910 - precision: 0.7475 - val_loss: 1.4187 - val_accuracy: 0.5126 - val_recall: 0.3977 - val_precision: 0.6355 - lr: 1.0000e-04
# Epoch 10/40
# 897/897 [==============================] - ETA: 0s - loss: 1.0283 - accuracy: 0.6349 - recall: 0.5054 - precision: 0.7547
# Epoch 10: val_accuracy improved from 0.61998 to 0.63281, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 224s 250ms/step - loss: 1.0283 - accuracy: 0.6349 - recall: 0.5054 - precision: 0.7547 - val_loss: 1.0639 - val_accuracy: 0.6328 - val_recall: 0.5472 - val_precision: 0.7224 - lr: 1.0000e-04
# Epoch 11/40
# 897/897 [==============================] - ETA: 0s - loss: 0.9871 - accuracy: 0.6504 - recall: 0.5271 - precision: 0.7659
# Epoch 11: val_accuracy did not improve from 0.63281
# 897/897 [==============================] - 225s 251ms/step - loss: 0.9871 - accuracy: 0.6504 - recall: 0.5271 - precision: 0.7659 - val_loss: 1.1598 - val_accuracy: 0.6105 - val_recall: 0.5530 - val_precision: 0.6662 - lr: 1.0000e-04
# Epoch 12/40
# 897/897 [==============================] - ETA: 0s - loss: 0.9632 - accuracy: 0.6608 - recall: 0.5367 - precision: 0.7631
# Epoch 12: val_accuracy improved from 0.63281 to 0.63407, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 223s 249ms/step - loss: 0.9632 - accuracy: 0.6608 - recall: 0.5367 - precision: 0.7631 - val_loss: 1.0254 - val_accuracy: 0.6341 - val_recall: 0.5328 - val_precision: 0.7274 - lr: 1.0000e-04
# Epoch 13/40
# 897/897 [==============================] - ETA: 0s - loss: 0.9266 - accuracy: 0.6687 - recall: 0.5541 - precision: 0.7733
# Epoch 13: val_accuracy did not improve from 0.63407
# 897/897 [==============================] - 222s 248ms/step - loss: 0.9266 - accuracy: 0.6687 - recall: 0.5541 - precision: 0.7733 - val_loss: 1.0375 - val_accuracy: 0.6327 - val_recall: 0.5342 - val_precision: 0.7412 - lr: 1.0000e-04
# Epoch 14/40
# 897/897 [==============================] - ETA: 0s - loss: 0.8996 - accuracy: 0.6823 - recall: 0.5719 - precision: 0.7776
# Epoch 14: val_accuracy did not improve from 0.63407
# 897/897 [==============================] - 225s 250ms/step - loss: 0.8996 - accuracy: 0.6823 - recall: 0.5719 - precision: 0.7776 - val_loss: 1.1259 - val_accuracy: 0.5988 - val_recall: 0.5073 - val_precision: 0.6996 - lr: 1.0000e-04
# Epoch 15/40
# 897/897 [==============================] - ETA: 0s - loss: 0.8863 - accuracy: 0.6847 - recall: 0.5793 - precision: 0.7813
# Epoch 15: val_accuracy did not improve from 0.63407
# 897/897 [==============================] - 224s 250ms/step - loss: 0.8863 - accuracy: 0.6847 - recall: 0.5793 - precision: 0.7813 - val_loss: 1.0895 - val_accuracy: 0.6154 - val_recall: 0.5367 - val_precision: 0.6810 - lr: 1.0000e-04
# Epoch 16/40
# 897/897 [==============================] - ETA: 0s - loss: 0.8686 - accuracy: 0.6939 - recall: 0.5883 - precision: 0.7848
# Epoch 16: val_accuracy did not improve from 0.63407
# 897/897 [==============================] - 224s 249ms/step - loss: 0.8686 - accuracy: 0.6939 - recall: 0.5883 - precision: 0.7848 - val_loss: 1.1969 - val_accuracy: 0.6095 - val_recall: 0.5350 - val_precision: 0.6878 - lr: 1.0000e-04
# Epoch 17/40
# 897/897 [==============================] - ETA: 0s - loss: 0.8415 - accuracy: 0.7007 - recall: 0.6026 - precision: 0.7891
# Epoch 17: val_accuracy improved from 0.63407 to 0.66420, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 223s 248ms/step - loss: 0.8415 - accuracy: 0.7007 - recall: 0.6026 - precision: 0.7891 - val_loss: 0.9901 - val_accuracy: 0.6642 - val_recall: 0.5992 - val_precision: 0.7348 - lr: 1.0000e-04
# Epoch 18/40
# 897/897 [==============================] - ETA: 0s - loss: 0.8224 - accuracy: 0.7093 - recall: 0.6157 - precision: 0.7931
# Epoch 18: val_accuracy did not improve from 0.66420
# 897/897 [==============================] - 222s 247ms/step - loss: 0.8224 - accuracy: 0.7093 - recall: 0.6157 - precision: 0.7931 - val_loss: 1.0198 - val_accuracy: 0.6500 - val_recall: 0.5858 - val_precision: 0.7216 - lr: 1.0000e-04
# Epoch 19/40
# 897/897 [==============================] - ETA: 0s - loss: 0.7954 - accuracy: 0.7206 - recall: 0.6325 - precision: 0.8012
# Epoch 19: val_accuracy improved from 0.66420 to 0.66574, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 223s 248ms/step - loss: 0.7954 - accuracy: 0.7206 - recall: 0.6325 - precision: 0.8012 - val_loss: 1.0097 - val_accuracy: 0.6657 - val_recall: 0.6011 - val_precision: 0.7262 - lr: 1.0000e-04
# Epoch 20/40
# 897/897 [==============================] - ETA: 0s - loss: 0.7717 - accuracy: 0.7286 - recall: 0.6402 - precision: 0.8094
# Epoch 20: val_accuracy did not improve from 0.66574
# 897/897 [==============================] - 222s 248ms/step - loss: 0.7717 - accuracy: 0.7286 - recall: 0.6402 - precision: 0.8094 - val_loss: 1.0408 - val_accuracy: 0.6568 - val_recall: 0.6166 - val_precision: 0.7066 - lr: 1.0000e-04
# Epoch 21/40
# 897/897 [==============================] - ETA: 0s - loss: 0.7583 - accuracy: 0.7327 - recall: 0.6500 - precision: 0.8089
# Epoch 21: val_accuracy improved from 0.66574 to 0.66769, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 224s 250ms/step - loss: 0.7583 - accuracy: 0.7327 - recall: 0.6500 - precision: 0.8089 - val_loss: 1.0026 - val_accuracy: 0.6677 - val_recall: 0.6105 - val_precision: 0.7256 - lr: 1.0000e-04
# Epoch 22/40
# 897/897 [==============================] - ETA: 0s - loss: 0.7362 - accuracy: 0.7436 - recall: 0.6621 - precision: 0.8157
# Epoch 22: val_accuracy improved from 0.66769 to 0.67899, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 227s 253ms/step - loss: 0.7362 - accuracy: 0.7436 - recall: 0.6621 - precision: 0.8157 - val_loss: 0.9358 - val_accuracy: 0.6790 - val_recall: 0.6155 - val_precision: 0.7406 - lr: 1.0000e-04
# Epoch 23/40
# 897/897 [==============================] - ETA: 0s - loss: 0.7092 - accuracy: 0.7523 - recall: 0.6772 - precision: 0.8205
# Epoch 23: val_accuracy did not improve from 0.67899
# 897/897 [==============================] - 227s 253ms/step - loss: 0.7092 - accuracy: 0.7523 - recall: 0.6772 - precision: 0.8205 - val_loss: 1.0185 - val_accuracy: 0.6749 - val_recall: 0.6324 - val_precision: 0.7275 - lr: 1.0000e-04
# Epoch 24/40
# 897/897 [==============================] - ETA: 0s - loss: 0.6985 - accuracy: 0.7551 - recall: 0.6835 - precision: 0.8241
# Epoch 24: val_accuracy did not improve from 0.67899
# 897/897 [==============================] - 224s 250ms/step - loss: 0.6985 - accuracy: 0.7551 - recall: 0.6835 - precision: 0.8241 - val_loss: 1.0753 - val_accuracy: 0.6371 - val_recall: 0.5879 - val_precision: 0.6943 - lr: 1.0000e-04
# Epoch 25/40
# 897/897 [==============================] - ETA: 0s - loss: 0.6773 - accuracy: 0.7673 - recall: 0.6992 - precision: 0.8284
# Epoch 25: val_accuracy did not improve from 0.67899
# 897/897 [==============================] - 222s 247ms/step - loss: 0.6773 - accuracy: 0.7673 - recall: 0.6992 - precision: 0.8284 - val_loss: 1.0252 - val_accuracy: 0.6755 - val_recall: 0.6385 - val_precision: 0.7206 - lr: 1.0000e-04
# Epoch 26/40
# 897/897 [==============================] - ETA: 0s - loss: 0.6586 - accuracy: 0.7713 - recall: 0.7059 - precision: 0.8312
# Epoch 26: val_accuracy improved from 0.67899 to 0.69587, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 223s 248ms/step - loss: 0.6586 - accuracy: 0.7713 - recall: 0.7059 - precision: 0.8312 - val_loss: 0.9815 - val_accuracy: 0.6959 - val_recall: 0.6490 - val_precision: 0.7364 - lr: 1.0000e-04
# Epoch 27/40
# 897/897 [==============================] - ETA: 0s - loss: 0.6403 - accuracy: 0.7806 - recall: 0.7165 - precision: 0.8389
# Epoch 27: val_accuracy did not improve from 0.69587
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 897/897 [==============================] - 223s 248ms/step - loss: 0.6403 - accuracy: 0.7806 - recall: 0.7165 - precision: 0.8389 - val_loss: 1.1397 - val_accuracy: 0.6526 - val_recall: 0.6159 - val_precision: 0.6907 - lr: 1.0000e-04
# Epoch 28/40
# 897/897 [==============================] - ETA: 0s - loss: 0.5208 - accuracy: 0.8232 - recall: 0.7746 - precision: 0.8691
# Epoch 28: val_accuracy improved from 0.69587 to 0.70884, saving model to cp_resnet_test_model.h5
# 897/897 [==============================] - 224s 249ms/step - loss: 0.5208 - accuracy: 0.8232 - recall: 0.7746 - precision: 0.8691 - val_loss: 0.9904 - val_accuracy: 0.7088 - val_recall: 0.6811 - val_precision: 0.7360 - lr: 2.0000e-05
# Epoch 29/40
# 897/897 [==============================] - ETA: 0s - loss: 0.4687 - accuracy: 0.8407 - recall: 0.8059 - precision: 0.8776
# Epoch 29: val_accuracy did not improve from 0.70884
# 897/897 [==============================] - 233s 259ms/step - loss: 0.4687 - accuracy: 0.8407 - recall: 0.8059 - precision: 0.8776 - val_loss: 1.0065 - val_accuracy: 0.6971 - val_recall: 0.6680 - val_precision: 0.7304 - lr: 2.0000e-05
# Epoch 30/40
# 897/897 [==============================] - ETA: 0s - loss: 0.4325 - accuracy: 0.8549 - recall: 0.8208 - precision: 0.8863
# Epoch 30: val_accuracy did not improve from 0.70884
# 897/897 [==============================] - 227s 253ms/step - loss: 0.4325 - accuracy: 0.8549 - recall: 0.8208 - precision: 0.8863 - val_loss: 1.0176 - val_accuracy: 0.7034 - val_recall: 0.6811 - val_precision: 0.7336 - lr: 2.0000e-05
# Epoch 31/40
# 897/897 [==============================] - ETA: 0s - loss: 0.4194 - accuracy: 0.8575 - recall: 0.8274 - precision: 0.8871
# Epoch 31: val_accuracy did not improve from 0.70884
# 897/897 [==============================] - 235s 261ms/step - loss: 0.4194 - accuracy: 0.8575 - recall: 0.8274 - precision: 0.8871 - val_loss: 1.0541 - val_accuracy: 0.7041 - val_recall: 0.6812 - val_precision: 0.7330 - lr: 2.0000e-05
# Epoch 32/40
# 897/897 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8663 - recall: 0.8400 - precision: 0.8930
# Epoch 32: val_accuracy did not improve from 0.70884
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 897/897 [==============================] - 238s 265ms/step - loss: 0.3972 - accuracy: 0.8663 - recall: 0.8400 - precision: 0.8930 - val_loss: 1.0829 - val_accuracy: 0.7021 - val_recall: 0.6805 - val_precision: 0.7272 - lr: 2.0000e-05
# Epoch 33/40
# 897/897 [==============================] - ETA: 0s - loss: 0.3639 - accuracy: 0.8801 - recall: 0.8531 - precision: 0.9062
# Epoch 33: val_accuracy did not improve from 0.70884
# 897/897 [==============================] - 236s 263ms/step - loss: 0.3639 - accuracy: 0.8801 - recall: 0.8531 - precision: 0.9062 - val_loss: 1.0797 - val_accuracy: 0.7047 - val_recall: 0.6837 - val_precision: 0.7287 - lr: 4.0000e-06
# Epoch 34/40
# 897/897 [==============================] - ETA: 0s - loss: 0.3504 - accuracy: 0.8828 - recall: 0.8578 - precision: 0.9065
# Epoch 34: val_accuracy did not improve from 0.70884
# 897/897 [==============================] - 236s 263ms/step - loss: 0.3504 - accuracy: 0.8828 - recall: 0.8578 - precision: 0.9065 - val_loss: 1.0914 - val_accuracy: 0.7035 - val_recall: 0.6850 - val_precision: 0.7274 - lr: 4.0000e-06
# Epoch 35/40
# 897/897 [==============================] - ETA: 0s - loss: 0.3508 - accuracy: 0.8842 - recall: 0.8610 - precision: 0.9071
# Epoch 35: val_accuracy did not improve from 0.70884
# 897/897 [==============================] - 236s 263ms/step - loss: 0.3508 - accuracy: 0.8842 - recall: 0.8610 - precision: 0.9071 - val_loss: 1.1011 - val_accuracy: 0.7044 - val_recall: 0.6855 - val_precision: 0.7288 - lr: 4.0000e-06
# Epoch 36/40
# 897/897 [==============================] - ETA: 0s - loss: 0.3502 - accuracy: 0.8821 - recall: 0.8587 - precision: 0.9056
# Epoch 36: val_accuracy did not improve from 0.70884
# 897/897 [==============================] - 237s 263ms/step - loss: 0.3502 - accuracy: 0.8821 - recall: 0.8587 - precision: 0.9056 - val_loss: 1.1041 - val_accuracy: 0.7065 - val_recall: 0.6878 - val_precision: 0.7289 - lr: 4.0000e-06
# Epoch 37/40
# 897/897 [==============================] - ETA: 0s - loss: 0.3367 - accuracy: 0.8872 - recall: 0.8663 - precision: 0.9092
# Epoch 37: val_accuracy did not improve from 0.70884
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 897/897 [==============================] - 235s 262ms/step - loss: 0.3367 - accuracy: 0.8872 - recall: 0.8663 - precision: 0.9092 - val_loss: 1.1152 - val_accuracy: 0.7056 - val_recall: 0.6878 - val_precision: 0.7294 - lr: 4.0000e-06
# Epoch 38/40
# 897/897 [==============================] - ETA: 0s - loss: 0.3371 - accuracy: 0.8873 - recall: 0.8650 - precision: 0.9098
# Epoch 38: val_accuracy did not improve from 0.70884
# 897/897 [==============================] - 236s 263ms/step - loss: 0.3371 - accuracy: 0.8873 - recall: 0.8650 - precision: 0.9098 - val_loss: 1.1122 - val_accuracy: 0.7056 - val_recall: 0.6869 - val_precision: 0.7276 - lr: 8.0000e-07
# Epoch 39/40
# 897/897 [==============================] - ETA: 0s - loss: 0.3283 - accuracy: 0.8908 - recall: 0.8681 - precision: 0.9124
# Epoch 39: val_accuracy did not improve from 0.70884
# 897/897 [==============================] - 237s 264ms/step - loss: 0.3283 - accuracy: 0.8908 - recall: 0.8681 - precision: 0.9124 - val_loss: 1.1175 - val_accuracy: 0.7051 - val_recall: 0.6860 - val_precision: 0.7261 - lr: 8.0000e-07
# Epoch 40/40
# 897/897 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.8890 - recall: 0.8694 - precision: 0.9103
# Epoch 40: val_accuracy did not improve from 0.70884
# 897/897 [==============================] - 236s 263ms/step - loss: 0.3289 - accuracy: 0.8890 - recall: 0.8694 - precision: 0.9103 - val_loss: 1.1196 - val_accuracy: 0.7038 - val_recall: 0.6869 - val_precision: 0.7264 - lr: 8.0000e-07
# 1/1 [==============================] - 1s 765ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 1s 760ms/step

# %% [markdown]
# # CK+ Dataset

# %%
import os
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, Flatten
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.applications import ResNet50
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.metrics import Precision, Recall
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import pandas as pd

# Set image dimensions
IMG_HEIGHT, IMG_WIDTH = 224, 224
batch_size = 16
train_data_dir = 'CK+48'

# Initialize data generators training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2
)

# Train data generator
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Validation data generator
validation_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)

# Load ResNet50 model, pre-trained on ImageNet, without the top layer
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# Freezeing layer
for layer in base_model.layers[:20]:
    layer.trainable = False

# Create the top model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu', kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(7, activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy', Recall(name='recall'), Precision(name='precision')])
model.summary()

# Setup callbacks for efficient training
checkpoint = ModelCheckpoint('cp_resnet_test_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-7, verbose=1)

# Training process
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.n // validation_generator.batch_size,
    epochs=40,  # Increased epochs for more training
    callbacks=[checkpoint, reduce_lr],
    verbose=1
)

# Save model to local machine
model.save('resnet50_test_model_ck+.h5')

# Plotting the training results 
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

plt.subplot(1, 2, 1)
plt.plot(history.history['recall'], label='Train Recall')
plt.plot(history.history['val_recall'], label='Validation Recall')
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()

plt.subplot(1, 2, 2)
plt.plot(history.history['precision'], label='Train Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

validation_generator.reset()
val_steps = validation_generator.n // validation_generator.batch_size + 1
y_true = []
y_pred = []

# Predict on validation data
for _ in range(val_steps):
    x, y = next(validation_generator)
    y_true.extend(np.argmax(y, axis=1))
    y_pred.extend(np.argmax(model.predict(x), axis=1))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=validation_generator.class_indices.keys())

# Plot confusion matrix
plt.figure(figsize=(10, 8))
cm_display.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.title('Confusion Matrix - Resnet-50')
plt.show()
# Out:
# Found 788 images belonging to 7 classes.
# Found 193 images belonging to 7 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 24,115,079
# Trainable params: 23,959,751
# Non-trainable params: 155,328
# _________________________________________________________________
# Epoch 1/40
# 49/49 [==============================] - ETA: 0s - loss: 6.6497 - accuracy: 0.3394 - recall: 0.2565 - precision: 0.4361
# Epoch 1: val_accuracy improved from -inf to 0.25521, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 15s 184ms/step - loss: 6.6497 - accuracy: 0.3394 - recall: 0.2565 - precision: 0.4361 - val_loss: 6.5000 - val_accuracy: 0.2552 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/40
# 49/49 [==============================] - ETA: 0s - loss: 5.8593 - accuracy: 0.5609 - recall: 0.4598 - precision: 0.6611
# Epoch 2: val_accuracy did not improve from 0.25521
# 49/49 [==============================] - 7s 146ms/step - loss: 5.8593 - accuracy: 0.5609 - recall: 0.4598 - precision: 0.6611 - val_loss: 6.6668 - val_accuracy: 0.1458 - val_recall: 0.1094 - val_precision: 0.1628 - lr: 1.0000e-04
# Epoch 3/40
# 49/49 [==============================] - ETA: 0s - loss: 5.5694 - accuracy: 0.6334 - recall: 0.5453 - precision: 0.7052
# Epoch 3: val_accuracy did not improve from 0.25521
# 49/49 [==============================] - 7s 148ms/step - loss: 5.5694 - accuracy: 0.6334 - recall: 0.5453 - precision: 0.7052 - val_loss: 7.2961 - val_accuracy: 0.1458 - val_recall: 0.1042 - val_precision: 0.1471 - lr: 1.0000e-04
# Epoch 4/40
# 49/49 [==============================] - ETA: 0s - loss: 5.1221 - accuracy: 0.7332 - recall: 0.6619 - precision: 0.8282
# Epoch 4: val_accuracy did not improve from 0.25521
# 49/49 [==============================] - 8s 152ms/step - loss: 5.1221 - accuracy: 0.7332 - recall: 0.6619 - precision: 0.8282 - val_loss: 7.3144 - val_accuracy: 0.1146 - val_recall: 0.0365 - val_precision: 0.1296 - lr: 1.0000e-04
# Epoch 5/40
# 48/49 [============================>.] - ETA: 0s - loss: 4.9238 - accuracy: 0.8008 - recall: 0.7604 - precision: 0.8488
# Epoch 5: val_accuracy did not improve from 0.25521
# 49/49 [==============================] - 7s 147ms/step - loss: 4.9224 - accuracy: 0.8005 - recall: 0.7604 - precision: 0.8495 - val_loss: 7.5738 - val_accuracy: 0.1354 - val_recall: 0.1354 - val_precision: 0.1453 - lr: 1.0000e-04
# Epoch 6/40
# 49/49 [==============================] - ETA: 0s - loss: 4.7753 - accuracy: 0.8061 - recall: 0.7628 - precision: 0.8531
# Epoch 6: val_accuracy did not improve from 0.25521
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 49/49 [==============================] - 8s 153ms/step - loss: 4.7753 - accuracy: 0.8061 - recall: 0.7628 - precision: 0.8531 - val_loss: 7.2969 - val_accuracy: 0.2031 - val_recall: 0.1823 - val_precision: 0.2011 - lr: 1.0000e-04
# Epoch 7/40
# 49/49 [==============================] - ETA: 0s - loss: 4.5997 - accuracy: 0.8575 - recall: 0.8381 - precision: 0.8887
# Epoch 7: val_accuracy improved from 0.25521 to 0.38542, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 8s 160ms/step - loss: 4.5997 - accuracy: 0.8575 - recall: 0.8381 - precision: 0.8887 - val_loss: 6.2728 - val_accuracy: 0.3854 - val_recall: 0.3385 - val_precision: 0.4483 - lr: 2.0000e-05
# Epoch 8/40
# 49/49 [==============================] - ETA: 0s - loss: 4.5299 - accuracy: 0.8782 - recall: 0.8627 - precision: 0.9199
# Epoch 8: val_accuracy improved from 0.38542 to 0.64583, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 8s 157ms/step - loss: 4.5299 - accuracy: 0.8782 - recall: 0.8627 - precision: 0.9199 - val_loss: 5.2914 - val_accuracy: 0.6458 - val_recall: 0.5781 - val_precision: 0.7070 - lr: 2.0000e-05
# Epoch 9/40
# 49/49 [==============================] - ETA: 0s - loss: 4.4369 - accuracy: 0.8990 - recall: 0.8601 - precision: 0.9197
# Epoch 9: val_accuracy improved from 0.64583 to 0.78646, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 8s 155ms/step - loss: 4.4369 - accuracy: 0.8990 - recall: 0.8601 - precision: 0.9197 - val_loss: 4.6932 - val_accuracy: 0.7865 - val_recall: 0.7500 - val_precision: 0.8571 - lr: 2.0000e-05
# Epoch 10/40
# 49/49 [==============================] - ETA: 0s - loss: 4.4303 - accuracy: 0.8977 - recall: 0.8769 - precision: 0.9149
# Epoch 10: val_accuracy improved from 0.78646 to 0.85417, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 8s 159ms/step - loss: 4.4303 - accuracy: 0.8977 - recall: 0.8769 - precision: 0.9149 - val_loss: 4.5474 - val_accuracy: 0.8542 - val_recall: 0.8177 - val_precision: 0.9128 - lr: 2.0000e-05
# Epoch 11/40
# 49/49 [==============================] - ETA: 0s - loss: 4.3812 - accuracy: 0.9158 - recall: 0.8977 - precision: 0.9365
# Epoch 11: val_accuracy did not improve from 0.85417
# 49/49 [==============================] - 7s 146ms/step - loss: 4.3812 - accuracy: 0.9158 - recall: 0.8977 - precision: 0.9365 - val_loss: 4.5002 - val_accuracy: 0.8542 - val_recall: 0.8177 - val_precision: 0.8920 - lr: 2.0000e-05
# Epoch 12/40
# 49/49 [==============================] - ETA: 0s - loss: 4.3295 - accuracy: 0.9184 - recall: 0.9016 - precision: 0.9380
# Epoch 12: val_accuracy improved from 0.85417 to 0.85938, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 8s 160ms/step - loss: 4.3295 - accuracy: 0.9184 - recall: 0.9016 - precision: 0.9380 - val_loss: 4.4578 - val_accuracy: 0.8594 - val_recall: 0.8490 - val_precision: 0.8763 - lr: 2.0000e-05
# Epoch 13/40
# 49/49 [==============================] - ETA: 0s - loss: 4.3459 - accuracy: 0.9236 - recall: 0.9080 - precision: 0.9384
# Epoch 13: val_accuracy did not improve from 0.85938
# 49/49 [==============================] - 7s 148ms/step - loss: 4.3459 - accuracy: 0.9236 - recall: 0.9080 - precision: 0.9384 - val_loss: 4.4915 - val_accuracy: 0.8490 - val_recall: 0.8177 - val_precision: 0.8579 - lr: 2.0000e-05
# Epoch 14/40
# 49/49 [==============================] - ETA: 0s - loss: 4.3180 - accuracy: 0.9119 - recall: 0.8899 - precision: 0.9259
# Epoch 14: val_accuracy improved from 0.85938 to 0.89062, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 8s 161ms/step - loss: 4.3180 - accuracy: 0.9119 - recall: 0.8899 - precision: 0.9259 - val_loss: 4.3430 - val_accuracy: 0.8906 - val_recall: 0.8750 - val_precision: 0.9180 - lr: 2.0000e-05
# Epoch 15/40
# 49/49 [==============================] - ETA: 0s - loss: 4.2792 - accuracy: 0.9236 - recall: 0.9119 - precision: 0.9374
# Epoch 15: val_accuracy did not improve from 0.89062
# 49/49 [==============================] - 7s 150ms/step - loss: 4.2792 - accuracy: 0.9236 - recall: 0.9119 - precision: 0.9374 - val_loss: 4.3673 - val_accuracy: 0.8646 - val_recall: 0.8594 - val_precision: 0.8919 - lr: 2.0000e-05
# Epoch 16/40
# 49/49 [==============================] - ETA: 0s - loss: 4.2252 - accuracy: 0.9339 - recall: 0.9210 - precision: 0.9455
# Epoch 16: val_accuracy did not improve from 0.89062
# 49/49 [==============================] - 7s 144ms/step - loss: 4.2252 - accuracy: 0.9339 - recall: 0.9210 - precision: 0.9455 - val_loss: 4.4100 - val_accuracy: 0.8385 - val_recall: 0.8125 - val_precision: 0.8571 - lr: 2.0000e-05
# Epoch 17/40
# 49/49 [==============================] - ETA: 0s - loss: 4.1777 - accuracy: 0.9365 - recall: 0.9262 - precision: 0.9483
# Epoch 17: val_accuracy did not improve from 0.89062
# 49/49 [==============================] - 7s 143ms/step - loss: 4.1777 - accuracy: 0.9365 - recall: 0.9262 - precision: 0.9483 - val_loss: 4.4223 - val_accuracy: 0.8750 - val_recall: 0.8490 - val_precision: 0.8907 - lr: 2.0000e-05
# Epoch 18/40
# 49/49 [==============================] - ETA: 0s - loss: 4.1290 - accuracy: 0.9534 - recall: 0.9456 - precision: 0.9656
# Epoch 18: val_accuracy did not improve from 0.89062
# 49/49 [==============================] - 7s 148ms/step - loss: 4.1290 - accuracy: 0.9534 - recall: 0.9456 - precision: 0.9656 - val_loss: 4.3284 - val_accuracy: 0.8594 - val_recall: 0.8438 - val_precision: 0.9000 - lr: 2.0000e-05
# Epoch 19/40
# 49/49 [==============================] - ETA: 0s - loss: 4.1669 - accuracy: 0.9352 - recall: 0.9210 - precision: 0.9417
# Epoch 19: val_accuracy did not improve from 0.89062
# 49/49 [==============================] - 7s 143ms/step - loss: 4.1669 - accuracy: 0.9352 - recall: 0.9210 - precision: 0.9417 - val_loss: 4.2746 - val_accuracy: 0.8854 - val_recall: 0.8698 - val_precision: 0.8978 - lr: 2.0000e-05
# Epoch 20/40
# 49/49 [==============================] - ETA: 0s - loss: 4.1212 - accuracy: 0.9443 - recall: 0.9326 - precision: 0.9511
# Epoch 20: val_accuracy did not improve from 0.89062
# 49/49 [==============================] - 7s 141ms/step - loss: 4.1212 - accuracy: 0.9443 - recall: 0.9326 - precision: 0.9511 - val_loss: 4.2512 - val_accuracy: 0.8906 - val_recall: 0.8854 - val_precision: 0.9043 - lr: 2.0000e-05
# Epoch 21/40
# 49/49 [==============================] - ETA: 0s - loss: 4.1182 - accuracy: 0.9391 - recall: 0.9301 - precision: 0.9472
# Epoch 21: val_accuracy did not improve from 0.89062
# 49/49 [==============================] - 7s 144ms/step - loss: 4.1182 - accuracy: 0.9391 - recall: 0.9301 - precision: 0.9472 - val_loss: 4.1500 - val_accuracy: 0.8906 - val_recall: 0.8854 - val_precision: 0.9239 - lr: 2.0000e-05
# Epoch 22/40
# 49/49 [==============================] - ETA: 0s - loss: 4.0608 - accuracy: 0.9482 - recall: 0.9352 - precision: 0.9588
# Epoch 22: val_accuracy did not improve from 0.89062
# 49/49 [==============================] - 7s 145ms/step - loss: 4.0608 - accuracy: 0.9482 - recall: 0.9352 - precision: 0.9588 - val_loss: 4.2312 - val_accuracy: 0.8750 - val_recall: 0.8385 - val_precision: 0.8944 - lr: 2.0000e-05
# Epoch 23/40
# 49/49 [==============================] - ETA: 0s - loss: 4.0171 - accuracy: 0.9637 - recall: 0.9560 - precision: 0.9660
# Epoch 23: val_accuracy did not improve from 0.89062
# 49/49 [==============================] - 7s 142ms/step - loss: 4.0171 - accuracy: 0.9637 - recall: 0.9560 - precision: 0.9660 - val_loss: 4.1927 - val_accuracy: 0.8750 - val_recall: 0.8594 - val_precision: 0.9066 - lr: 2.0000e-05
# Epoch 24/40
# 49/49 [==============================] - ETA: 0s - loss: 3.9476 - accuracy: 0.9676 - recall: 0.9573 - precision: 0.9749
# Epoch 24: val_accuracy did not improve from 0.89062
# 49/49 [==============================] - 7s 143ms/step - loss: 3.9476 - accuracy: 0.9676 - recall: 0.9573 - precision: 0.9749 - val_loss: 4.1971 - val_accuracy: 0.8698 - val_recall: 0.8542 - val_precision: 0.8962 - lr: 2.0000e-05
# Epoch 25/40
# 49/49 [==============================] - ETA: 0s - loss: 3.9706 - accuracy: 0.9417 - recall: 0.9391 - precision: 0.9502
# Epoch 25: val_accuracy improved from 0.89062 to 0.90104, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 8s 157ms/step - loss: 3.9706 - accuracy: 0.9417 - recall: 0.9391 - precision: 0.9502 - val_loss: 4.1185 - val_accuracy: 0.9010 - val_recall: 0.8906 - val_precision: 0.9293 - lr: 2.0000e-05
# Epoch 26/40
# 49/49 [==============================] - ETA: 0s - loss: 3.9533 - accuracy: 0.9560 - recall: 0.9482 - precision: 0.9632
# Epoch 26: val_accuracy did not improve from 0.90104
# 49/49 [==============================] - 7s 144ms/step - loss: 3.9533 - accuracy: 0.9560 - recall: 0.9482 - precision: 0.9632 - val_loss: 4.1237 - val_accuracy: 0.8906 - val_recall: 0.8646 - val_precision: 0.9022 - lr: 2.0000e-05
# Epoch 27/40
# 49/49 [==============================] - ETA: 0s - loss: 3.9046 - accuracy: 0.9585 - recall: 0.9534 - precision: 0.9608
# Epoch 27: val_accuracy did not improve from 0.90104
# 49/49 [==============================] - 7s 145ms/step - loss: 3.9046 - accuracy: 0.9585 - recall: 0.9534 - precision: 0.9608 - val_loss: 4.0880 - val_accuracy: 0.8802 - val_recall: 0.8542 - val_precision: 0.8817 - lr: 2.0000e-05
# Epoch 28/40
# 49/49 [==============================] - ETA: 0s - loss: 3.8868 - accuracy: 0.9611 - recall: 0.9573 - precision: 0.9660
# Epoch 28: val_accuracy did not improve from 0.90104
# 49/49 [==============================] - 7s 146ms/step - loss: 3.8868 - accuracy: 0.9611 - recall: 0.9573 - precision: 0.9660 - val_loss: 4.0568 - val_accuracy: 0.8750 - val_recall: 0.8490 - val_precision: 0.8859 - lr: 2.0000e-05
# Epoch 29/40
# 49/49 [==============================] - ETA: 0s - loss: 3.8613 - accuracy: 0.9560 - recall: 0.9508 - precision: 0.9582
# Epoch 29: val_accuracy improved from 0.90104 to 0.90625, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 8s 160ms/step - loss: 3.8613 - accuracy: 0.9560 - recall: 0.9508 - precision: 0.9582 - val_loss: 3.9811 - val_accuracy: 0.9062 - val_recall: 0.8750 - val_precision: 0.9180 - lr: 2.0000e-05
# Epoch 30/40
# 49/49 [==============================] - ETA: 0s - loss: 3.8081 - accuracy: 0.9689 - recall: 0.9624 - precision: 0.9789
# Epoch 30: val_accuracy did not improve from 0.90625
# 49/49 [==============================] - 7s 147ms/step - loss: 3.8081 - accuracy: 0.9689 - recall: 0.9624 - precision: 0.9789 - val_loss: 4.0461 - val_accuracy: 0.8646 - val_recall: 0.8542 - val_precision: 0.9011 - lr: 2.0000e-05
# Epoch 31/40
# 49/49 [==============================] - ETA: 0s - loss: 3.7881 - accuracy: 0.9689 - recall: 0.9637 - precision: 0.9688
# Epoch 31: val_accuracy did not improve from 0.90625
# 49/49 [==============================] - 7s 140ms/step - loss: 3.7881 - accuracy: 0.9689 - recall: 0.9637 - precision: 0.9688 - val_loss: 3.9899 - val_accuracy: 0.8906 - val_recall: 0.8802 - val_precision: 0.9185 - lr: 2.0000e-05
# Epoch 32/40
# 49/49 [==============================] - ETA: 0s - loss: 3.7332 - accuracy: 0.9741 - recall: 0.9728 - precision: 0.9766
# Epoch 32: val_accuracy did not improve from 0.90625
# 49/49 [==============================] - 7s 143ms/step - loss: 3.7332 - accuracy: 0.9741 - recall: 0.9728 - precision: 0.9766 - val_loss: 3.9543 - val_accuracy: 0.8854 - val_recall: 0.8750 - val_precision: 0.9130 - lr: 2.0000e-05
# Epoch 33/40
# 49/49 [==============================] - ETA: 0s - loss: 3.7409 - accuracy: 0.9650 - recall: 0.9611 - precision: 0.9750
# Epoch 33: val_accuracy did not improve from 0.90625
# 49/49 [==============================] - 7s 144ms/step - loss: 3.7409 - accuracy: 0.9650 - recall: 0.9611 - precision: 0.9750 - val_loss: 3.9602 - val_accuracy: 0.8958 - val_recall: 0.8906 - val_precision: 0.9096 - lr: 2.0000e-05
# Epoch 34/40
# 49/49 [==============================] - ETA: 0s - loss: 3.7502 - accuracy: 0.9560 - recall: 0.9534 - precision: 0.9608
# Epoch 34: val_accuracy did not improve from 0.90625
# 49/49 [==============================] - 7s 144ms/step - loss: 3.7502 - accuracy: 0.9560 - recall: 0.9534 - precision: 0.9608 - val_loss: 3.9982 - val_accuracy: 0.8854 - val_recall: 0.8490 - val_precision: 0.9056 - lr: 2.0000e-05
# Epoch 35/40
# 49/49 [==============================] - ETA: 0s - loss: 3.6749 - accuracy: 0.9715 - recall: 0.9689 - precision: 0.9727
# Epoch 35: val_accuracy did not improve from 0.90625
# 49/49 [==============================] - 7s 148ms/step - loss: 3.6749 - accuracy: 0.9715 - recall: 0.9689 - precision: 0.9727 - val_loss: 3.9064 - val_accuracy: 0.8854 - val_recall: 0.8646 - val_precision: 0.9071 - lr: 2.0000e-05
# Epoch 36/40
# 49/49 [==============================] - ETA: 0s - loss: 3.6468 - accuracy: 0.9715 - recall: 0.9650 - precision: 0.9764
# Epoch 36: val_accuracy did not improve from 0.90625
# 49/49 [==============================] - 7s 151ms/step - loss: 3.6468 - accuracy: 0.9715 - recall: 0.9650 - precision: 0.9764 - val_loss: 3.9777 - val_accuracy: 0.8698 - val_recall: 0.8698 - val_precision: 0.8883 - lr: 2.0000e-05
# Epoch 37/40
# 49/49 [==============================] - ETA: 0s - loss: 3.6047 - accuracy: 0.9741 - recall: 0.9715 - precision: 0.9778
# Epoch 37: val_accuracy did not improve from 0.90625
# 49/49 [==============================] - 7s 143ms/step - loss: 3.6047 - accuracy: 0.9741 - recall: 0.9715 - precision: 0.9778 - val_loss: 3.8453 - val_accuracy: 0.9010 - val_recall: 0.8958 - val_precision: 0.9101 - lr: 2.0000e-05
# Epoch 38/40
# 49/49 [==============================] - ETA: 0s - loss: 3.5963 - accuracy: 0.9728 - recall: 0.9650 - precision: 0.9739
# Epoch 38: val_accuracy improved from 0.90625 to 0.92708, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 8s 154ms/step - loss: 3.5963 - accuracy: 0.9728 - recall: 0.9650 - precision: 0.9739 - val_loss: 3.7432 - val_accuracy: 0.9271 - val_recall: 0.9219 - val_precision: 0.9415 - lr: 2.0000e-05
# Epoch 39/40
# 49/49 [==============================] - ETA: 0s - loss: 3.5610 - accuracy: 0.9767 - recall: 0.9689 - precision: 0.9816
# Epoch 39: val_accuracy improved from 0.92708 to 0.93750, saving model to cp_resnet_test_model.h5
# 49/49 [==============================] - 8s 156ms/step - loss: 3.5610 - accuracy: 0.9767 - recall: 0.9689 - precision: 0.9816 - val_loss: 3.6861 - val_accuracy: 0.9375 - val_recall: 0.9271 - val_precision: 0.9418 - lr: 2.0000e-05
# Epoch 40/40
# 49/49 [==============================] - ETA: 0s - loss: 3.5254 - accuracy: 0.9767 - recall: 0.9702 - precision: 0.9791
# Epoch 40: val_accuracy did not improve from 0.93750
# 49/49 [==============================] - 7s 147ms/step - loss: 3.5254 - accuracy: 0.9767 - recall: 0.9702 - precision: 0.9791 - val_loss: 3.7129 - val_accuracy: 0.9115 - val_recall: 0.9010 - val_precision: 0.9301 - lr: 2.0000e-05
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 118ms/step

# %% [markdown]
# # RAF-DB

# %%
import os
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, Flatten
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.applications import ResNet50
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.metrics import Precision, Recall
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import pandas as pd

# Set image dimensions
IMG_HEIGHT, IMG_WIDTH = 224, 224
batch_size = 32
train_data_dir = 'RAF-DB/DATASET/train'
val_data_dir = 'RAF-DB/DATASET/test'

# Initialize data generators training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
)

# Initialize data generators validation
val_datagen = ImageDataGenerator(
    rescale=1./255,
)

# Train data generator
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Validation data generator
validation_generator = val_datagen.flow_from_directory(
    val_data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Load ResNet50 model, pre-trained on ImageNet, without the top layer
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# Freezeing layer
for layer in base_model.layers[:20]:
    layer.trainable = False

# Create the top model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu', kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(7, activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy', Recall(name='recall'), Precision(name='precision')])
model.summary()

# Setup callbacks for efficient training
checkpoint = ModelCheckpoint('cp_resnet_test_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-7, verbose=1)

# Training process
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.n // validation_generator.batch_size,
    epochs=40,  # Increased epochs for more training
    callbacks=[checkpoint, reduce_lr],
    verbose=1
)

# Save model to local machine
model.save('resnet50_test_model_raf.h5')

# Plotting the training results 
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

plt.subplot(1, 2, 1)
plt.plot(history.history['recall'], label='Train Recall')
plt.plot(history.history['val_recall'], label='Validation Recall')
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()

plt.subplot(1, 2, 2)
plt.plot(history.history['precision'], label='Train Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

validation_generator.reset()
val_steps = validation_generator.n // validation_generator.batch_size + 1
y_true = []
y_pred = []

# Predict on validation data
for _ in range(val_steps):
    x, y = next(validation_generator)
    y_true.extend(np.argmax(y, axis=1))
    y_pred.extend(np.argmax(model.predict(x), axis=1))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=validation_generator.class_indices.keys())

# Plot confusion matrix
plt.figure(figsize=(10, 8))
cm_display.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.title('Confusion Matrix - Resnet-50')
plt.show()
# Out:
# Found 12271 images belonging to 7 classes.
# Found 3068 images belonging to 7 classes.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_4   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 256)               524544
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 24,115,079
# Trainable params: 23,959,751
# Non-trainable params: 155,328
# _________________________________________________________________
# Epoch 1/40
# 383/383 [==============================] - ETA: 0s - loss: 6.2956 - accuracy: 0.3487 - recall: 0.1936 - precision: 0.4648
# Epoch 1: val_accuracy improved from -inf to 0.20461, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 106s 265ms/step - loss: 6.2956 - accuracy: 0.3487 - recall: 0.1936 - precision: 0.4648 - val_loss: 5.8922 - val_accuracy: 0.2046 - val_recall: 0.1661 - val_precision: 0.3176 - lr: 1.0000e-04
# Epoch 2/40
# 383/383 [==============================] - ETA: 0s - loss: 4.9028 - accuracy: 0.5469 - recall: 0.3780 - precision: 0.7002
# Epoch 2: val_accuracy improved from 0.20461 to 0.60691, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 100s 260ms/step - loss: 4.9028 - accuracy: 0.5469 - recall: 0.3780 - precision: 0.7002 - val_loss: 4.3542 - val_accuracy: 0.6069 - val_recall: 0.4503 - val_precision: 0.7376 - lr: 1.0000e-04
# Epoch 3/40
# 383/383 [==============================] - ETA: 0s - loss: 3.9396 - accuracy: 0.6244 - recall: 0.4946 - precision: 0.7305
# Epoch 3: val_accuracy improved from 0.60691 to 0.68882, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 100s 261ms/step - loss: 3.9396 - accuracy: 0.6244 - recall: 0.4946 - precision: 0.7305 - val_loss: 3.3437 - val_accuracy: 0.6888 - val_recall: 0.6181 - val_precision: 0.7495 - lr: 1.0000e-04
# Epoch 4/40
# 383/383 [==============================] - ETA: 0s - loss: 3.1006 - accuracy: 0.6774 - recall: 0.5807 - precision: 0.7679
# Epoch 4: val_accuracy improved from 0.68882 to 0.71217, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 100s 261ms/step - loss: 3.1006 - accuracy: 0.6774 - recall: 0.5807 - precision: 0.7679 - val_loss: 2.7590 - val_accuracy: 0.7122 - val_recall: 0.5901 - val_precision: 0.8052 - lr: 1.0000e-04
# Epoch 5/40
# 383/383 [==============================] - ETA: 0s - loss: 2.4239 - accuracy: 0.7127 - recall: 0.6255 - precision: 0.7940
# Epoch 5: val_accuracy improved from 0.71217 to 0.73454, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 100s 262ms/step - loss: 2.4239 - accuracy: 0.7127 - recall: 0.6255 - precision: 0.7940 - val_loss: 2.1188 - val_accuracy: 0.7345 - val_recall: 0.6711 - val_precision: 0.8051 - lr: 1.0000e-04
# Epoch 6/40
# 383/383 [==============================] - ETA: 0s - loss: 1.9003 - accuracy: 0.7345 - recall: 0.6652 - precision: 0.8024
# Epoch 6: val_accuracy improved from 0.73454 to 0.73487, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 100s 261ms/step - loss: 1.9003 - accuracy: 0.7345 - recall: 0.6652 - precision: 0.8024 - val_loss: 1.6993 - val_accuracy: 0.7349 - val_recall: 0.6836 - val_precision: 0.7919 - lr: 1.0000e-04
# Epoch 7/40
# 383/383 [==============================] - ETA: 0s - loss: 1.5138 - accuracy: 0.7506 - recall: 0.6858 - precision: 0.8110
# Epoch 7: val_accuracy improved from 0.73487 to 0.75888, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 101s 263ms/step - loss: 1.5138 - accuracy: 0.7506 - recall: 0.6858 - precision: 0.8110 - val_loss: 1.4253 - val_accuracy: 0.7589 - val_recall: 0.6947 - val_precision: 0.8101 - lr: 1.0000e-04
# Epoch 8/40
# 383/383 [==============================] - ETA: 0s - loss: 1.2426 - accuracy: 0.7629 - recall: 0.7039 - precision: 0.8185
# Epoch 8: val_accuracy did not improve from 0.75888
# 383/383 [==============================] - 99s 259ms/step - loss: 1.2426 - accuracy: 0.7629 - recall: 0.7039 - precision: 0.8185 - val_loss: 1.2587 - val_accuracy: 0.7184 - val_recall: 0.6592 - val_precision: 0.7912 - lr: 1.0000e-04
# Epoch 9/40
# 383/383 [==============================] - ETA: 0s - loss: 1.0298 - accuracy: 0.7832 - recall: 0.7273 - precision: 0.8340
# Epoch 9: val_accuracy improved from 0.75888 to 0.78355, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 100s 261ms/step - loss: 1.0298 - accuracy: 0.7832 - recall: 0.7273 - precision: 0.8340 - val_loss: 0.9792 - val_accuracy: 0.7836 - val_recall: 0.7523 - val_precision: 0.8185 - lr: 1.0000e-04
# Epoch 10/40
# 383/383 [==============================] - ETA: 0s - loss: 0.8975 - accuracy: 0.7845 - recall: 0.7329 - precision: 0.8329
# Epoch 10: val_accuracy did not improve from 0.78355
# 383/383 [==============================] - 98s 256ms/step - loss: 0.8975 - accuracy: 0.7845 - recall: 0.7329 - precision: 0.8329 - val_loss: 0.9417 - val_accuracy: 0.7651 - val_recall: 0.7401 - val_precision: 0.7996 - lr: 1.0000e-04
# Epoch 11/40
# 383/383 [==============================] - ETA: 0s - loss: 0.7964 - accuracy: 0.7917 - recall: 0.7416 - precision: 0.8378
# Epoch 11: val_accuracy improved from 0.78355 to 0.81974, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 96s 251ms/step - loss: 0.7964 - accuracy: 0.7917 - recall: 0.7416 - precision: 0.8378 - val_loss: 0.6855 - val_accuracy: 0.8197 - val_recall: 0.7819 - val_precision: 0.8584 - lr: 1.0000e-04
# Epoch 12/40
# 383/383 [==============================] - ETA: 0s - loss: 0.7209 - accuracy: 0.8015 - recall: 0.7550 - precision: 0.8484
# Epoch 12: val_accuracy did not improve from 0.81974
# 383/383 [==============================] - 96s 249ms/step - loss: 0.7209 - accuracy: 0.8015 - recall: 0.7550 - precision: 0.8484 - val_loss: 0.8346 - val_accuracy: 0.7641 - val_recall: 0.7391 - val_precision: 0.7971 - lr: 1.0000e-04
# Epoch 13/40
# 383/383 [==============================] - ETA: 0s - loss: 0.6907 - accuracy: 0.8001 - recall: 0.7522 - precision: 0.8445
# Epoch 13: val_accuracy did not improve from 0.81974
# 383/383 [==============================] - 95s 249ms/step - loss: 0.6907 - accuracy: 0.8001 - recall: 0.7522 - precision: 0.8445 - val_loss: 0.6603 - val_accuracy: 0.8164 - val_recall: 0.7730 - val_precision: 0.8539 - lr: 1.0000e-04
# Epoch 14/40
# 383/383 [==============================] - ETA: 0s - loss: 0.6320 - accuracy: 0.8162 - recall: 0.7761 - precision: 0.8542
# Epoch 14: val_accuracy did not improve from 0.81974
# 383/383 [==============================] - 96s 249ms/step - loss: 0.6320 - accuracy: 0.8162 - recall: 0.7761 - precision: 0.8542 - val_loss: 0.6287 - val_accuracy: 0.8138 - val_recall: 0.7901 - val_precision: 0.8437 - lr: 1.0000e-04
# Epoch 15/40
# 383/383 [==============================] - ETA: 0s - loss: 0.5807 - accuracy: 0.8243 - recall: 0.7854 - precision: 0.8625
# Epoch 15: val_accuracy did not improve from 0.81974
# 383/383 [==============================] - 96s 249ms/step - loss: 0.5807 - accuracy: 0.8243 - recall: 0.7854 - precision: 0.8625 - val_loss: 0.7807 - val_accuracy: 0.7701 - val_recall: 0.7503 - val_precision: 0.7953 - lr: 1.0000e-04
# Epoch 16/40
# 383/383 [==============================] - ETA: 0s - loss: 0.5349 - accuracy: 0.8360 - recall: 0.8053 - precision: 0.8708
# Epoch 16: val_accuracy improved from 0.81974 to 0.83125, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 96s 251ms/step - loss: 0.5349 - accuracy: 0.8360 - recall: 0.8053 - precision: 0.8708 - val_loss: 0.5854 - val_accuracy: 0.8313 - val_recall: 0.8082 - val_precision: 0.8618 - lr: 1.0000e-04
# Epoch 17/40
# 383/383 [==============================] - ETA: 0s - loss: 0.5335 - accuracy: 0.8359 - recall: 0.8020 - precision: 0.8727
# Epoch 17: val_accuracy did not improve from 0.83125
# 383/383 [==============================] - 96s 249ms/step - loss: 0.5335 - accuracy: 0.8359 - recall: 0.8020 - precision: 0.8727 - val_loss: 0.6645 - val_accuracy: 0.8023 - val_recall: 0.7826 - val_precision: 0.8255 - lr: 1.0000e-04
# Epoch 18/40
# 383/383 [==============================] - ETA: 0s - loss: 0.4838 - accuracy: 0.8485 - recall: 0.8198 - precision: 0.8796
# Epoch 18: val_accuracy did not improve from 0.83125
# 383/383 [==============================] - 96s 249ms/step - loss: 0.4838 - accuracy: 0.8485 - recall: 0.8198 - precision: 0.8796 - val_loss: 0.6602 - val_accuracy: 0.8066 - val_recall: 0.7724 - val_precision: 0.8404 - lr: 1.0000e-04
# Epoch 19/40
# 383/383 [==============================] - ETA: 0s - loss: 0.4695 - accuracy: 0.8552 - recall: 0.8220 - precision: 0.8799
# Epoch 19: val_accuracy did not improve from 0.83125
# 383/383 [==============================] - 96s 249ms/step - loss: 0.4695 - accuracy: 0.8552 - recall: 0.8220 - precision: 0.8799 - val_loss: 0.6112 - val_accuracy: 0.8207 - val_recall: 0.7852 - val_precision: 0.8489 - lr: 1.0000e-04
# Epoch 20/40
# 383/383 [==============================] - ETA: 0s - loss: 0.4531 - accuracy: 0.8586 - recall: 0.8302 - precision: 0.8843
# Epoch 20: val_accuracy did not improve from 0.83125
# 383/383 [==============================] - 96s 249ms/step - loss: 0.4531 - accuracy: 0.8586 - recall: 0.8302 - precision: 0.8843 - val_loss: 0.6455 - val_accuracy: 0.8066 - val_recall: 0.7822 - val_precision: 0.8309 - lr: 1.0000e-04
# Epoch 21/40
# 383/383 [==============================] - ETA: 0s - loss: 0.4282 - accuracy: 0.8667 - recall: 0.8417 - precision: 0.8928
# Epoch 21: val_accuracy did not improve from 0.83125
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 383/383 [==============================] - 95s 249ms/step - loss: 0.4282 - accuracy: 0.8667 - recall: 0.8417 - precision: 0.8928 - val_loss: 0.7925 - val_accuracy: 0.7783 - val_recall: 0.7523 - val_precision: 0.8011 - lr: 1.0000e-04
# Epoch 22/40
# 383/383 [==============================] - ETA: 0s - loss: 0.3232 - accuracy: 0.9020 - recall: 0.8820 - precision: 0.9235
# Epoch 22: val_accuracy improved from 0.83125 to 0.85855, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 96s 251ms/step - loss: 0.3232 - accuracy: 0.9020 - recall: 0.8820 - precision: 0.9235 - val_loss: 0.5018 - val_accuracy: 0.8586 - val_recall: 0.8470 - val_precision: 0.8747 - lr: 2.0000e-05
# Epoch 23/40
# 383/383 [==============================] - ETA: 0s - loss: 0.2622 - accuracy: 0.9234 - recall: 0.9111 - precision: 0.9363
# Epoch 23: val_accuracy did not improve from 0.85855
# 383/383 [==============================] - 96s 249ms/step - loss: 0.2622 - accuracy: 0.9234 - recall: 0.9111 - precision: 0.9363 - val_loss: 0.5184 - val_accuracy: 0.8582 - val_recall: 0.8480 - val_precision: 0.8739 - lr: 2.0000e-05
# Epoch 24/40
# 383/383 [==============================] - ETA: 0s - loss: 0.2479 - accuracy: 0.9260 - recall: 0.9154 - precision: 0.9370
# Epoch 24: val_accuracy did not improve from 0.85855
# 383/383 [==============================] - 96s 249ms/step - loss: 0.2479 - accuracy: 0.9260 - recall: 0.9154 - precision: 0.9370 - val_loss: 0.5283 - val_accuracy: 0.8546 - val_recall: 0.8431 - val_precision: 0.8688 - lr: 2.0000e-05
# Epoch 25/40
# 383/383 [==============================] - ETA: 0s - loss: 0.2200 - accuracy: 0.9364 - recall: 0.9269 - precision: 0.9458
# Epoch 25: val_accuracy did not improve from 0.85855
# 383/383 [==============================] - 95s 249ms/step - loss: 0.2200 - accuracy: 0.9364 - recall: 0.9269 - precision: 0.9458 - val_loss: 0.5501 - val_accuracy: 0.8579 - val_recall: 0.8500 - val_precision: 0.8712 - lr: 2.0000e-05
# Epoch 26/40
# 383/383 [==============================] - ETA: 0s - loss: 0.2051 - accuracy: 0.9404 - recall: 0.9319 - precision: 0.9481
# Epoch 26: val_accuracy did not improve from 0.85855
# 383/383 [==============================] - 96s 249ms/step - loss: 0.2051 - accuracy: 0.9404 - recall: 0.9319 - precision: 0.9481 - val_loss: 0.5577 - val_accuracy: 0.8493 - val_recall: 0.8398 - val_precision: 0.8645 - lr: 2.0000e-05
# Epoch 27/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1910 - accuracy: 0.9430 - recall: 0.9364 - precision: 0.9505
# Epoch 27: val_accuracy did not improve from 0.85855
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 383/383 [==============================] - 96s 249ms/step - loss: 0.1910 - accuracy: 0.9430 - recall: 0.9364 - precision: 0.9505 - val_loss: 0.5595 - val_accuracy: 0.8513 - val_recall: 0.8411 - val_precision: 0.8647 - lr: 2.0000e-05
# Epoch 28/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1667 - accuracy: 0.9518 - recall: 0.9455 - precision: 0.9585
# Epoch 28: val_accuracy improved from 0.85855 to 0.86053, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 96s 251ms/step - loss: 0.1667 - accuracy: 0.9518 - recall: 0.9455 - precision: 0.9585 - val_loss: 0.5356 - val_accuracy: 0.8605 - val_recall: 0.8530 - val_precision: 0.8728 - lr: 4.0000e-06
# Epoch 29/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1648 - accuracy: 0.9542 - recall: 0.9496 - precision: 0.9594
# Epoch 29: val_accuracy did not improve from 0.86053
# 383/383 [==============================] - 96s 249ms/step - loss: 0.1648 - accuracy: 0.9542 - recall: 0.9496 - precision: 0.9594 - val_loss: 0.5330 - val_accuracy: 0.8605 - val_recall: 0.8546 - val_precision: 0.8730 - lr: 4.0000e-06
# Epoch 30/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9566 - recall: 0.9513 - precision: 0.9644
# Epoch 30: val_accuracy did not improve from 0.86053
# 383/383 [==============================] - 96s 249ms/step - loss: 0.1561 - accuracy: 0.9566 - recall: 0.9513 - precision: 0.9644 - val_loss: 0.5414 - val_accuracy: 0.8599 - val_recall: 0.8516 - val_precision: 0.8717 - lr: 4.0000e-06
# Epoch 31/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9553 - recall: 0.9514 - precision: 0.9606
# Epoch 31: val_accuracy did not improve from 0.86053
# 383/383 [==============================] - 96s 249ms/step - loss: 0.1518 - accuracy: 0.9553 - recall: 0.9514 - precision: 0.9606 - val_loss: 0.5495 - val_accuracy: 0.8602 - val_recall: 0.8516 - val_precision: 0.8697 - lr: 4.0000e-06
# Epoch 32/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9605 - recall: 0.9551 - precision: 0.9656
# Epoch 32: val_accuracy did not improve from 0.86053
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 383/383 [==============================] - 95s 248ms/step - loss: 0.1439 - accuracy: 0.9605 - recall: 0.9551 - precision: 0.9656 - val_loss: 0.5529 - val_accuracy: 0.8586 - val_recall: 0.8480 - val_precision: 0.8704 - lr: 4.0000e-06
# Epoch 33/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1405 - accuracy: 0.9605 - recall: 0.9547 - precision: 0.9652
# Epoch 33: val_accuracy did not improve from 0.86053
# 383/383 [==============================] - 95s 248ms/step - loss: 0.1405 - accuracy: 0.9605 - recall: 0.9547 - precision: 0.9652 - val_loss: 0.5538 - val_accuracy: 0.8602 - val_recall: 0.8480 - val_precision: 0.8686 - lr: 8.0000e-07
# Epoch 34/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9614 - recall: 0.9571 - precision: 0.9659
# Epoch 34: val_accuracy did not improve from 0.86053
# 383/383 [==============================] - 95s 248ms/step - loss: 0.1392 - accuracy: 0.9614 - recall: 0.9571 - precision: 0.9659 - val_loss: 0.5557 - val_accuracy: 0.8586 - val_recall: 0.8493 - val_precision: 0.8676 - lr: 8.0000e-07
# Epoch 35/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9642 - recall: 0.9597 - precision: 0.9691
# Epoch 35: val_accuracy did not improve from 0.86053
# 383/383 [==============================] - 95s 248ms/step - loss: 0.1389 - accuracy: 0.9642 - recall: 0.9597 - precision: 0.9691 - val_loss: 0.5575 - val_accuracy: 0.8605 - val_recall: 0.8520 - val_precision: 0.8703 - lr: 8.0000e-07
# Epoch 36/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9614 - recall: 0.9570 - precision: 0.9655
# Epoch 36: val_accuracy improved from 0.86053 to 0.86118, saving model to cp_resnet_test_model.h5
# 383/383 [==============================] - 96s 251ms/step - loss: 0.1446 - accuracy: 0.9614 - recall: 0.9570 - precision: 0.9655 - val_loss: 0.5520 - val_accuracy: 0.8612 - val_recall: 0.8530 - val_precision: 0.8719 - lr: 8.0000e-07
# Epoch 37/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9622 - recall: 0.9563 - precision: 0.9683
# Epoch 37: val_accuracy did not improve from 0.86118
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 383/383 [==============================] - 96s 249ms/step - loss: 0.1353 - accuracy: 0.9622 - recall: 0.9563 - precision: 0.9683 - val_loss: 0.5549 - val_accuracy: 0.8592 - val_recall: 0.8507 - val_precision: 0.8707 - lr: 8.0000e-07
# Epoch 38/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9623 - recall: 0.9578 - precision: 0.9676
# Epoch 38: val_accuracy did not improve from 0.86118
# 383/383 [==============================] - 97s 252ms/step - loss: 0.1352 - accuracy: 0.9623 - recall: 0.9578 - precision: 0.9676 - val_loss: 0.5536 - val_accuracy: 0.8602 - val_recall: 0.8520 - val_precision: 0.8700 - lr: 1.6000e-07
# Epoch 39/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9614 - recall: 0.9574 - precision: 0.9665
# Epoch 39: val_accuracy did not improve from 0.86118
# 383/383 [==============================] - 97s 253ms/step - loss: 0.1399 - accuracy: 0.9614 - recall: 0.9574 - precision: 0.9665 - val_loss: 0.5589 - val_accuracy: 0.8605 - val_recall: 0.8510 - val_precision: 0.8702 - lr: 1.6000e-07
# Epoch 40/40
# 383/383 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 0.9647 - recall: 0.9604 - precision: 0.9688
# Epoch 40: val_accuracy did not improve from 0.86118
# 383/383 [==============================] - 97s 253ms/step - loss: 0.1312 - accuracy: 0.9647 - recall: 0.9604 - precision: 0.9688 - val_loss: 0.5552 - val_accuracy: 0.8612 - val_recall: 0.8530 - val_precision: 0.8707 - lr: 1.6000e-07
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 1s 728ms/step
